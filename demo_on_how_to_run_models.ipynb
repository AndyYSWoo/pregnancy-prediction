# %% [markdown]
# This notebook illustrates how to run LR, BMS and LSTM models from [Predicting pregnancy using large-scale data from a women's health tracking mobile application](https://arxiv.org/abs/1812.02222) with generated data.

# %% [markdown]
# Due to privacy concerns, we will not release the actual user data from Clue app. Instead, we provide a synthetic data generator which assumes fertility changes over a cycle and sample symptoms (sex activities and emotions) to obtain a pregnancy probability. Read `data_gen.py` for more details.

# %%
from data_gen import *

# %% [markdown]
# First, we generate 10000 cycles using the data generator.

# %%
data = genCycleData(10000)

# %% [markdown]
# Each data entry consists of a array of symptom tuples (day_in_cycle, symptom_name) and a binary label indicating whether this user gets preganant during this cycle. For example, the first data entry is printed as follows:

# %%
print(data[0])
# Out:
# ([[0, 'emotion_sad'], [5, 'emotion_neutral'], [6, 'unprotected_sex'], [7, 'emotion_neutral'], [8, 'emotion_neutral'], [15, 'withdrawl_sex'], [16, 'emotion_happy'], [16, 'unprotected_sex'], [18, 'emotion_sad'], [23, 'emotion_sad']], 0)

# %% [markdown]
# Next, we convert, split and store the generated data into train / dev / test files as required by the models.

# %%
dataNpy = convertToNdarray(data)
splitAndSave(dataNpy, 0.8, 0.1, 0.1, "./data/generated/")

# %% [markdown]
# Finally, we could fit the model by running the entry point file `main.py`.
#
# As an example, we fit a logistic regression model for 50 epochs on our generated model:

# %%
! python main.py \
    --experiment_name='Demo' \
    --data_dir='./data/' \
    --folder_name='generated' \
    --tb_dir='./experiments/' \
    --model='LR' \
    --num_epochs=50 \
    --batch_size=500
# Out:
# /Volumes/Macintosh HD/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:root:Prediction on per-cycle basis, using data:
# 	training data: ./data/generated/train,
# 	dev data: ./data/generated/dev/dev.npy,
# 	test data: ./data/generated/test/test.npy.
# 2019-02-21 17:17:49.049790: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Summary name LogisticRegression/fully_connected/weights:0 is illegal; using LogisticRegression/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name LogisticRegression/fully_connected/weights:0 is illegal; using LogisticRegression/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name LogisticRegression/fully_connected/biases:0 is illegal; using LogisticRegression/fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name LogisticRegression/fully_connected/biases:0 is illegal; using LogisticRegression/fully_connected/biases_0 instead.
# INFO:root:Epoch: 0, Iter: 10, (part) train loss: 0.4695, (part) train auc: 0.698, (part) train auprc: 0.285, dev loss: 0.3907, dev auc: 0.704, dev auprc: 0.262
# INFO:root:	Best dev auc so far: 0.704! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 0 took 0.24 seconds: 0.03 seconds for loading data
# INFO:root:Epoch: 1, Iter: 20, (part) train loss: 0.4026, (part) train auc: 0.703, (part) train auprc: 0.289, dev loss: 0.3828, dev auc: 0.707, dev auprc: 0.267
# INFO:root:	Best dev auc so far: 0.707! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 1, Iter: 30, (part) train loss: 0.4860, (part) train auc: 0.706, (part) train auprc: 0.293, dev loss: 0.3756, dev auc: 0.709, dev auprc: 0.274
# INFO:root:	Best dev auc so far: 0.709! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 1 took 0.14 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 2, Iter: 40, (part) train loss: 0.4688, (part) train auc: 0.708, (part) train auprc: 0.295, dev loss: 0.3689, dev auc: 0.712, dev auprc: 0.276
# INFO:root:	Best dev auc so far: 0.712! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 2 took 0.09 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 3, Iter: 50, (part) train loss: 0.4262, (part) train auc: 0.712, (part) train auprc: 0.300, dev loss: 0.3632, dev auc: 0.715, dev auprc: 0.280
# INFO:root:	Best dev auc so far: 0.715! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 3, Iter: 60, (part) train loss: 0.4150, (part) train auc: 0.714, (part) train auprc: 0.303, dev loss: 0.3583, dev auc: 0.718, dev auprc: 0.282
# INFO:root:	Best dev auc so far: 0.718! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 3 took 0.13 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 4, Iter: 70, (part) train loss: 0.3397, (part) train auc: 0.717, (part) train auprc: 0.307, dev loss: 0.3542, dev auc: 0.720, dev auprc: 0.288
# INFO:root:	Best dev auc so far: 0.720! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 4, Iter: 80, (part) train loss: 0.3967, (part) train auc: 0.721, (part) train auprc: 0.313, dev loss: 0.3509, dev auc: 0.724, dev auprc: 0.294
# INFO:root:	Best dev auc so far: 0.724! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 4 took 0.20 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 5, Iter: 90, (part) train loss: 0.3891, (part) train auc: 0.725, (part) train auprc: 0.319, dev loss: 0.3481, dev auc: 0.728, dev auprc: 0.299
# INFO:root:	Best dev auc so far: 0.728! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 5 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 6, Iter: 100, (part) train loss: 0.3633, (part) train auc: 0.731, (part) train auprc: 0.326, dev loss: 0.3460, dev auc: 0.732, dev auprc: 0.306
# INFO:root:	Best dev auc so far: 0.732! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 6, Iter: 110, (part) train loss: 0.4477, (part) train auc: 0.738, (part) train auprc: 0.335, dev loss: 0.3443, dev auc: 0.737, dev auprc: 0.315
# INFO:root:	Best dev auc so far: 0.737! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 6 took 0.13 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 7, Iter: 120, (part) train loss: 0.3968, (part) train auc: 0.745, (part) train auprc: 0.345, dev loss: 0.3429, dev auc: 0.743, dev auprc: 0.323
# INFO:root:	Best dev auc so far: 0.743! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 7 took 0.08 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 8, Iter: 130, (part) train loss: 0.3321, (part) train auc: 0.752, (part) train auprc: 0.356, dev loss: 0.3416, dev auc: 0.749, dev auprc: 0.334
# INFO:root:	Best dev auc so far: 0.749! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 8, Iter: 140, (part) train loss: 0.3662, (part) train auc: 0.760, (part) train auprc: 0.368, dev loss: 0.3405, dev auc: 0.756, dev auprc: 0.346
# INFO:root:	Best dev auc so far: 0.756! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 8 took 0.14 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 9, Iter: 150, (part) train loss: 0.3841, (part) train auc: 0.768, (part) train auprc: 0.380, dev loss: 0.3395, dev auc: 0.762, dev auprc: 0.355
# INFO:root:	Best dev auc so far: 0.762! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 9, Iter: 160, (part) train loss: 0.3642, (part) train auc: 0.776, (part) train auprc: 0.393, dev loss: 0.3385, dev auc: 0.770, dev auprc: 0.367
# INFO:root:	Best dev auc so far: 0.770! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 9 took 0.12 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 10, Iter: 170, (part) train loss: 0.3572, (part) train auc: 0.784, (part) train auprc: 0.407, dev loss: 0.3375, dev auc: 0.776, dev auprc: 0.381
# INFO:root:	Best dev auc so far: 0.776! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 10 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 11, Iter: 180, (part) train loss: 0.4117, (part) train auc: 0.793, (part) train auprc: 0.422, dev loss: 0.3365, dev auc: 0.784, dev auprc: 0.395
# INFO:root:	Best dev auc so far: 0.784! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 11, Iter: 190, (part) train loss: 0.3932, (part) train auc: 0.802, (part) train auprc: 0.437, dev loss: 0.3355, dev auc: 0.791, dev auprc: 0.407
# INFO:root:	Best dev auc so far: 0.791! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 11 took 0.16 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 12, Iter: 200, (part) train loss: 0.3943, (part) train auc: 0.810, (part) train auprc: 0.452, dev loss: 0.3344, dev auc: 0.798, dev auprc: 0.418
# INFO:root:	Best dev auc so far: 0.798! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 12 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 13, Iter: 210, (part) train loss: 0.3855, (part) train auc: 0.818, (part) train auprc: 0.468, dev loss: 0.3333, dev auc: 0.804, dev auprc: 0.430
# INFO:root:	Best dev auc so far: 0.804! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 13, Iter: 220, (part) train loss: 0.4472, (part) train auc: 0.826, (part) train auprc: 0.483, dev loss: 0.3321, dev auc: 0.811, dev auprc: 0.446
# INFO:root:	Best dev auc so far: 0.811! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 13 took 0.12 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 14, Iter: 230, (part) train loss: 0.3977, (part) train auc: 0.833, (part) train auprc: 0.497, dev loss: 0.3311, dev auc: 0.817, dev auprc: 0.458
# INFO:root:	Best dev auc so far: 0.817! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 14, Iter: 240, (part) train loss: 0.3838, (part) train auc: 0.840, (part) train auprc: 0.511, dev loss: 0.3300, dev auc: 0.823, dev auprc: 0.469
# INFO:root:	Best dev auc so far: 0.823! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 14 took 0.12 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 15, Iter: 250, (part) train loss: 0.3510, (part) train auc: 0.848, (part) train auprc: 0.526, dev loss: 0.3288, dev auc: 0.829, dev auprc: 0.479
# INFO:root:	Best dev auc so far: 0.829! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 15 took 0.09 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 16, Iter: 260, (part) train loss: 0.3374, (part) train auc: 0.854, (part) train auprc: 0.539, dev loss: 0.3276, dev auc: 0.835, dev auprc: 0.488
# INFO:root:	Best dev auc so far: 0.835! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 16, Iter: 270, (part) train loss: 0.3438, (part) train auc: 0.860, (part) train auprc: 0.552, dev loss: 0.3265, dev auc: 0.841, dev auprc: 0.498
# INFO:root:	Best dev auc so far: 0.841! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 16 took 0.13 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 17, Iter: 280, (part) train loss: 0.3493, (part) train auc: 0.866, (part) train auprc: 0.566, dev loss: 0.3253, dev auc: 0.846, dev auprc: 0.508
# INFO:root:	Best dev auc so far: 0.846! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 17 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 18, Iter: 290, (part) train loss: 0.3525, (part) train auc: 0.871, (part) train auprc: 0.577, dev loss: 0.3242, dev auc: 0.851, dev auprc: 0.516
# INFO:root:	Best dev auc so far: 0.851! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 18, Iter: 300, (part) train loss: 0.3818, (part) train auc: 0.876, (part) train auprc: 0.588, dev loss: 0.3232, dev auc: 0.855, dev auprc: 0.525
# INFO:root:	Best dev auc so far: 0.855! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 18 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 19, Iter: 310, (part) train loss: 0.3532, (part) train auc: 0.880, (part) train auprc: 0.598, dev loss: 0.3220, dev auc: 0.859, dev auprc: 0.533
# INFO:root:	Best dev auc so far: 0.859! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 19, Iter: 320, (part) train loss: 0.3292, (part) train auc: 0.885, (part) train auprc: 0.609, dev loss: 0.3209, dev auc: 0.863, dev auprc: 0.542
# INFO:root:	Best dev auc so far: 0.863! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 19 took 0.12 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 20, Iter: 330, (part) train loss: 0.3800, (part) train auc: 0.889, (part) train auprc: 0.620, dev loss: 0.3197, dev auc: 0.867, dev auprc: 0.550
# INFO:root:	Best dev auc so far: 0.867! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 20 took 0.08 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 21, Iter: 340, (part) train loss: 0.3537, (part) train auc: 0.893, (part) train auprc: 0.630, dev loss: 0.3185, dev auc: 0.871, dev auprc: 0.556
# INFO:root:	Best dev auc so far: 0.871! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 21, Iter: 350, (part) train loss: 0.3298, (part) train auc: 0.897, (part) train auprc: 0.638, dev loss: 0.3175, dev auc: 0.874, dev auprc: 0.563
# INFO:root:	Best dev auc so far: 0.874! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 21 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 22, Iter: 360, (part) train loss: 0.3633, (part) train auc: 0.900, (part) train auprc: 0.647, dev loss: 0.3164, dev auc: 0.877, dev auprc: 0.571
# INFO:root:	Best dev auc so far: 0.877! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 22 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 23, Iter: 370, (part) train loss: 0.3708, (part) train auc: 0.903, (part) train auprc: 0.654, dev loss: 0.3153, dev auc: 0.880, dev auprc: 0.577
# INFO:root:	Best dev auc so far: 0.880! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 23, Iter: 380, (part) train loss: 0.3257, (part) train auc: 0.906, (part) train auprc: 0.661, dev loss: 0.3143, dev auc: 0.882, dev auprc: 0.581
# INFO:root:	Best dev auc so far: 0.882! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 23 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 24, Iter: 390, (part) train loss: 0.3405, (part) train auc: 0.908, (part) train auprc: 0.669, dev loss: 0.3132, dev auc: 0.885, dev auprc: 0.587
# INFO:root:	Best dev auc so far: 0.885! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 24, Iter: 400, (part) train loss: 0.3456, (part) train auc: 0.911, (part) train auprc: 0.676, dev loss: 0.3121, dev auc: 0.887, dev auprc: 0.597
# INFO:root:	Best dev auc so far: 0.887! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 24 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 25, Iter: 410, (part) train loss: 0.3332, (part) train auc: 0.914, (part) train auprc: 0.683, dev loss: 0.3110, dev auc: 0.890, dev auprc: 0.604
# INFO:root:	Best dev auc so far: 0.890! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 25 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 26, Iter: 420, (part) train loss: 0.3296, (part) train auc: 0.916, (part) train auprc: 0.689, dev loss: 0.3099, dev auc: 0.892, dev auprc: 0.609
# INFO:root:	Best dev auc so far: 0.892! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 26, Iter: 430, (part) train loss: 0.3712, (part) train auc: 0.918, (part) train auprc: 0.695, dev loss: 0.3089, dev auc: 0.895, dev auprc: 0.613
# INFO:root:	Best dev auc so far: 0.895! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 26 took 0.10 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 27, Iter: 440, (part) train loss: 0.3612, (part) train auc: 0.920, (part) train auprc: 0.700, dev loss: 0.3079, dev auc: 0.897, dev auprc: 0.618
# INFO:root:	Best dev auc so far: 0.897! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 27 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 28, Iter: 450, (part) train loss: 0.3186, (part) train auc: 0.922, (part) train auprc: 0.705, dev loss: 0.3069, dev auc: 0.899, dev auprc: 0.621
# INFO:root:	Best dev auc so far: 0.899! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 28, Iter: 460, (part) train loss: 0.3629, (part) train auc: 0.924, (part) train auprc: 0.711, dev loss: 0.3058, dev auc: 0.900, dev auprc: 0.625
# INFO:root:	Best dev auc so far: 0.900! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 28 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 29, Iter: 470, (part) train loss: 0.3470, (part) train auc: 0.926, (part) train auprc: 0.716, dev loss: 0.3048, dev auc: 0.903, dev auprc: 0.631
# INFO:root:	Best dev auc so far: 0.903! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 29, Iter: 480, (part) train loss: 0.3079, (part) train auc: 0.927, (part) train auprc: 0.720, dev loss: 0.3038, dev auc: 0.904, dev auprc: 0.634
# INFO:root:	Best dev auc so far: 0.904! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 29 took 0.10 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 30, Iter: 490, (part) train loss: 0.2930, (part) train auc: 0.929, (part) train auprc: 0.725, dev loss: 0.3028, dev auc: 0.906, dev auprc: 0.640
# INFO:root:	Best dev auc so far: 0.906! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 30 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 31, Iter: 500, (part) train loss: 0.3443, (part) train auc: 0.930, (part) train auprc: 0.729, dev loss: 0.3018, dev auc: 0.907, dev auprc: 0.644
# INFO:root:	Best dev auc so far: 0.907! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 31, Iter: 510, (part) train loss: 0.3171, (part) train auc: 0.931, (part) train auprc: 0.732, dev loss: 0.3009, dev auc: 0.909, dev auprc: 0.648
# INFO:root:	Best dev auc so far: 0.909! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 31 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 32, Iter: 520, (part) train loss: 0.3328, (part) train auc: 0.932, (part) train auprc: 0.736, dev loss: 0.3001, dev auc: 0.910, dev auprc: 0.653
# INFO:root:	Best dev auc so far: 0.910! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 32 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 33, Iter: 530, (part) train loss: 0.3169, (part) train auc: 0.934, (part) train auprc: 0.740, dev loss: 0.2990, dev auc: 0.911, dev auprc: 0.656
# INFO:root:	Best dev auc so far: 0.911! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 33, Iter: 540, (part) train loss: 0.3261, (part) train auc: 0.935, (part) train auprc: 0.744, dev loss: 0.2979, dev auc: 0.913, dev auprc: 0.660
# INFO:root:	Best dev auc so far: 0.913! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 33 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 34, Iter: 550, (part) train loss: 0.3337, (part) train auc: 0.936, (part) train auprc: 0.747, dev loss: 0.2970, dev auc: 0.913, dev auprc: 0.662
# INFO:root:	Best dev auc so far: 0.913! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 34, Iter: 560, (part) train loss: 0.3111, (part) train auc: 0.937, (part) train auprc: 0.750, dev loss: 0.2961, dev auc: 0.914, dev auprc: 0.663
# INFO:root:	Best dev auc so far: 0.914! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 34 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 35, Iter: 570, (part) train loss: 0.3784, (part) train auc: 0.938, (part) train auprc: 0.753, dev loss: 0.2952, dev auc: 0.915, dev auprc: 0.666
# INFO:root:	Best dev auc so far: 0.915! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 35 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 36, Iter: 580, (part) train loss: 0.3037, (part) train auc: 0.939, (part) train auprc: 0.757, dev loss: 0.2942, dev auc: 0.916, dev auprc: 0.668
# INFO:root:	Best dev auc so far: 0.916! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 36, Iter: 590, (part) train loss: 0.3359, (part) train auc: 0.940, (part) train auprc: 0.760, dev loss: 0.2933, dev auc: 0.917, dev auprc: 0.670
# INFO:root:	Best dev auc so far: 0.917! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 36 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 37, Iter: 600, (part) train loss: 0.3000, (part) train auc: 0.941, (part) train auprc: 0.763, dev loss: 0.2923, dev auc: 0.919, dev auprc: 0.673
# INFO:root:	Best dev auc so far: 0.919! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 37 took 0.08 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 38, Iter: 610, (part) train loss: 0.3304, (part) train auc: 0.942, (part) train auprc: 0.766, dev loss: 0.2914, dev auc: 0.920, dev auprc: 0.676
# INFO:root:	Best dev auc so far: 0.920! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 38, Iter: 620, (part) train loss: 0.2991, (part) train auc: 0.943, (part) train auprc: 0.768, dev loss: 0.2905, dev auc: 0.921, dev auprc: 0.677
# INFO:root:	Best dev auc so far: 0.921! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 38 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 39, Iter: 630, (part) train loss: 0.3020, (part) train auc: 0.943, (part) train auprc: 0.771, dev loss: 0.2896, dev auc: 0.922, dev auprc: 0.680
# INFO:root:	Best dev auc so far: 0.922! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 39, Iter: 640, (part) train loss: 0.3134, (part) train auc: 0.944, (part) train auprc: 0.773, dev loss: 0.2888, dev auc: 0.922, dev auprc: 0.683
# INFO:root:	Best dev auc so far: 0.922! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 39 took 0.12 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 40, Iter: 650, (part) train loss: 0.3365, (part) train auc: 0.945, (part) train auprc: 0.776, dev loss: 0.2879, dev auc: 0.923, dev auprc: 0.685
# INFO:root:	Best dev auc so far: 0.923! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 40 took 0.09 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 41, Iter: 660, (part) train loss: 0.3231, (part) train auc: 0.946, (part) train auprc: 0.778, dev loss: 0.2870, dev auc: 0.924, dev auprc: 0.687
# INFO:root:	Best dev auc so far: 0.924! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 41, Iter: 670, (part) train loss: 0.3246, (part) train auc: 0.946, (part) train auprc: 0.780, dev loss: 0.2862, dev auc: 0.925, dev auprc: 0.688
# INFO:root:	Best dev auc so far: 0.925! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 41 took 0.13 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 42, Iter: 680, (part) train loss: 0.2777, (part) train auc: 0.947, (part) train auprc: 0.782, dev loss: 0.2853, dev auc: 0.926, dev auprc: 0.691
# INFO:root:	Best dev auc so far: 0.926! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 42 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 43, Iter: 690, (part) train loss: 0.2899, (part) train auc: 0.948, (part) train auprc: 0.784, dev loss: 0.2845, dev auc: 0.926, dev auprc: 0.694
# INFO:root:	Best dev auc so far: 0.926! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 43, Iter: 700, (part) train loss: 0.3272, (part) train auc: 0.948, (part) train auprc: 0.787, dev loss: 0.2835, dev auc: 0.927, dev auprc: 0.694
# INFO:root:	Best dev auc so far: 0.927! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 43 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 44, Iter: 710, (part) train loss: 0.2941, (part) train auc: 0.949, (part) train auprc: 0.789, dev loss: 0.2827, dev auc: 0.928, dev auprc: 0.695
# INFO:root:	Best dev auc so far: 0.928! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 44, Iter: 720, (part) train loss: 0.3043, (part) train auc: 0.949, (part) train auprc: 0.791, dev loss: 0.2819, dev auc: 0.928, dev auprc: 0.697
# INFO:root:	Best dev auc so far: 0.928! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 44 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 45, Iter: 730, (part) train loss: 0.3170, (part) train auc: 0.950, (part) train auprc: 0.793, dev loss: 0.2811, dev auc: 0.929, dev auprc: 0.697
# INFO:root:	Best dev auc so far: 0.929! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 45 took 0.07 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 46, Iter: 740, (part) train loss: 0.3074, (part) train auc: 0.951, (part) train auprc: 0.795, dev loss: 0.2802, dev auc: 0.929, dev auprc: 0.700
# INFO:root:	Best dev auc so far: 0.929! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 46, Iter: 750, (part) train loss: 0.2913, (part) train auc: 0.951, (part) train auprc: 0.796, dev loss: 0.2794, dev auc: 0.930, dev auprc: 0.700
# INFO:root:	Best dev auc so far: 0.930! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 46 took 0.11 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 47, Iter: 760, (part) train loss: 0.3207, (part) train auc: 0.951, (part) train auprc: 0.798, dev loss: 0.2787, dev auc: 0.930, dev auprc: 0.701
# INFO:root:	Best dev auc so far: 0.930! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 47 took 0.08 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 48, Iter: 770, (part) train loss: 0.3044, (part) train auc: 0.952, (part) train auprc: 0.799, dev loss: 0.2779, dev auc: 0.931, dev auprc: 0.703
# INFO:root:	Best dev auc so far: 0.931! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 48, Iter: 780, (part) train loss: 0.3208, (part) train auc: 0.952, (part) train auprc: 0.801, dev loss: 0.2770, dev auc: 0.931, dev auprc: 0.706
# INFO:root:	Best dev auc so far: 0.931! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 48 took 0.13 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 49, Iter: 790, (part) train loss: 0.3009, (part) train auc: 0.953, (part) train auprc: 0.803, dev loss: 0.2761, dev auc: 0.932, dev auprc: 0.707
# INFO:root:	Best dev auc so far: 0.932! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 49, Iter: 800, (part) train loss: 0.2897, (part) train auc: 0.953, (part) train auprc: 0.805, dev loss: 0.2754, dev auc: 0.932, dev auprc: 0.708
# INFO:root:	Best dev auc so far: 0.932! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 49 took 0.14 seconds: 0.01 seconds for loading data

# %% [markdown]
# The BMS model:

# %%
! python main.py \
    --experiment_name='Demo' \
    --data_dir='./data/' \
    --folder_name='generated' \
    --tb_dir='./experiments/' \
    --model='BMS' \
    --bms_model='lstm' \
    --num_epochs=10 \
    --batch_size=500
# Out:
# /Volumes/Macintosh HD/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:root:Prediction on per-cycle basis, using data:
# 	training data: ./data/generated/train,
# 	dev data: ./data/generated/dev/dev.npy,
# 	test data: ./data/generated/test/test.npy.
# 2019-02-21 17:17:59.208093: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Summary name lstm_b:0 is illegal; using lstm_b_0 instead.
# INFO:tensorflow:Summary name lstm_b:0 is illegal; using lstm_b_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using rnn/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using rnn/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using rnn/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using rnn/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using rnn/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using rnn/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using rnn/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name rnn/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using rnn/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected/weights:0 is illegal; using lstm_mlp/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected/weights:0 is illegal; using lstm_mlp/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected/biases:0 is illegal; using lstm_mlp/fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected/biases:0 is illegal; using lstm_mlp/fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected_1/weights:0 is illegal; using lstm_mlp/fully_connected_1/weights_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected_1/weights:0 is illegal; using lstm_mlp/fully_connected_1/weights_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected_1/biases:0 is illegal; using lstm_mlp/fully_connected_1/biases_0 instead.
# INFO:tensorflow:Summary name lstm_mlp/fully_connected_1/biases:0 is illegal; using lstm_mlp/fully_connected_1/biases_0 instead.
# INFO:tensorflow:Summary name fully_connected/weights:0 is illegal; using fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name fully_connected/weights:0 is illegal; using fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name fully_connected/biases:0 is illegal; using fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name fully_connected/biases:0 is illegal; using fully_connected/biases_0 instead.
# INFO:root:Epoch: 0, Iter: 10, (part) train loss: 0.3618, (part) train auc: 0.755, (part) train auprc: 0.350, dev loss: 0.3278, dev auc: 0.754, dev auprc: 0.265
# INFO:root:	Best dev auc so far: 0.754! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 0 took 5.14 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 1, Iter: 20, (part) train loss: 0.3578, (part) train auc: 0.812, (part) train auprc: 0.441, dev loss: 0.3322, dev auc: 0.809, dev auprc: 0.342
# INFO:root:	Best dev auc so far: 0.809! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 1, Iter: 30, (part) train loss: 0.3383, (part) train auc: 0.825, (part) train auprc: 0.461, dev loss: 0.3140, dev auc: 0.827, dev auprc: 0.358
# INFO:root:	Best dev auc so far: 0.827! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 1 took 6.19 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 2, Iter: 40, (part) train loss: 0.3714, (part) train auc: 0.862, (part) train auprc: 0.537, dev loss: 0.3118, dev auc: 0.862, dev auprc: 0.424
# INFO:root:	Best dev auc so far: 0.862! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 2 took 4.54 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 3, Iter: 50, (part) train loss: 0.3240, (part) train auc: 0.879, (part) train auprc: 0.574, dev loss: 0.2958, dev auc: 0.885, dev auprc: 0.481
# INFO:root:	Best dev auc so far: 0.885! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 3, Iter: 60, (part) train loss: 0.2903, (part) train auc: 0.896, (part) train auprc: 0.618, dev loss: 0.2862, dev auc: 0.904, dev auprc: 0.550
# INFO:root:	Best dev auc so far: 0.904! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 3 took 6.18 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 4, Iter: 70, (part) train loss: 0.2927, (part) train auc: 0.923, (part) train auprc: 0.695, dev loss: 0.2741, dev auc: 0.933, dev auprc: 0.637
# INFO:root:	Best dev auc so far: 0.933! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 4, Iter: 80, (part) train loss: 0.2748, (part) train auc: 0.950, (part) train auprc: 0.787, dev loss: 0.2628, dev auc: 0.951, dev auprc: 0.743
# INFO:root:	Best dev auc so far: 0.951! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 4 took 6.24 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 5, Iter: 90, (part) train loss: 0.2686, (part) train auc: 0.924, (part) train auprc: 0.705, dev loss: 0.2377, dev auc: 0.928, dev auprc: 0.605
# INFO:root:Epoch 5 took 4.60 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 6, Iter: 100, (part) train loss: 0.2360, (part) train auc: 0.918, (part) train auprc: 0.693, dev loss: 0.2251, dev auc: 0.923, dev auprc: 0.625
# INFO:root:Epoch: 6, Iter: 110, (part) train loss: 0.2564, (part) train auc: 0.930, (part) train auprc: 0.720, dev loss: 0.2290, dev auc: 0.933, dev auprc: 0.637
# INFO:root:Epoch 6 took 6.00 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 7, Iter: 120, (part) train loss: 0.2576, (part) train auc: 0.935, (part) train auprc: 0.750, dev loss: 0.2211, dev auc: 0.938, dev auprc: 0.683
# INFO:root:Epoch 7 took 4.59 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 8, Iter: 130, (part) train loss: 0.2656, (part) train auc: 0.931, (part) train auprc: 0.732, dev loss: 0.2249, dev auc: 0.933, dev auprc: 0.654
# INFO:root:Epoch: 8, Iter: 140, (part) train loss: 0.2389, (part) train auc: 0.932, (part) train auprc: 0.733, dev loss: 0.2192, dev auc: 0.935, dev auprc: 0.680
# INFO:root:Epoch 8 took 6.02 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 9, Iter: 150, (part) train loss: 0.2512, (part) train auc: 0.934, (part) train auprc: 0.733, dev loss: 0.2120, dev auc: 0.937, dev auprc: 0.709
# INFO:root:Epoch: 9, Iter: 160, (part) train loss: 0.2216, (part) train auc: 0.939, (part) train auprc: 0.756, dev loss: 0.2231, dev auc: 0.941, dev auprc: 0.728
# INFO:root:Epoch 9 took 6.21 seconds: 0.02 seconds for loading data

# %% [markdown]
# The LSTM model:

# %%
! python main.py \
    --experiment_name='Demo' \
    --data_dir='./data/' \
    --folder_name='generated' \
    --tb_dir='./experiments/' \
    --model='LSTM' \
    --num_epochs=10 \
    --batch_size=500 \
    --lstm_layer=2 \
    --lstm_size=100 \
    --fc_layer=2 \
    --fc_size=100
# Out:
# /Volumes/Macintosh HD/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:root:Prediction on per-cycle basis, using data:
# 	training data: ./data/generated/train,
# 	dev data: ./data/generated/dev/dev.npy,
# 	test data: ./data/generated/test/test.npy.
# 2019-02-21 17:19:00.521459: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Scale of 0 disables regularizer.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/bias:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_0/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/kernel_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/bias:0 is illegal; using LSTMModel/rnn/multi_rnn_cell/cell_1/lstm_cell/bias_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected/weights:0 is illegal; using LSTMModel/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected/weights:0 is illegal; using LSTMModel/fully_connected/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected/biases:0 is illegal; using LSTMModel/fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected/biases:0 is illegal; using LSTMModel/fully_connected/biases_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_1/weights:0 is illegal; using LSTMModel/fully_connected_1/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_1/weights:0 is illegal; using LSTMModel/fully_connected_1/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_1/biases:0 is illegal; using LSTMModel/fully_connected_1/biases_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_1/biases:0 is illegal; using LSTMModel/fully_connected_1/biases_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_2/weights:0 is illegal; using LSTMModel/fully_connected_2/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_2/weights:0 is illegal; using LSTMModel/fully_connected_2/weights_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_2/biases:0 is illegal; using LSTMModel/fully_connected_2/biases_0 instead.
# INFO:tensorflow:Summary name LSTMModel/fully_connected_2/biases:0 is illegal; using LSTMModel/fully_connected_2/biases_0 instead.
# INFO:root:Epoch: 0, Iter: 10, (part) train loss: 0.4079, (part) train auc: 0.781, (part) train auprc: 0.395, dev loss: 0.3434, dev auc: 0.776, dev auprc: 0.367
# INFO:root:	Best dev auc so far: 0.776! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 0 took 4.32 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 1, Iter: 20, (part) train loss: 0.3420, (part) train auc: 0.891, (part) train auprc: 0.607, dev loss: 0.3114, dev auc: 0.894, dev auprc: 0.540
# INFO:root:	Best dev auc so far: 0.894! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 1, Iter: 30, (part) train loss: 0.2761, (part) train auc: 0.929, (part) train auprc: 0.722, dev loss: 0.2207, dev auc: 0.935, dev auprc: 0.681
# INFO:root:	Best dev auc so far: 0.935! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 1 took 4.74 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 2, Iter: 40, (part) train loss: 0.2214, (part) train auc: 0.938, (part) train auprc: 0.754, dev loss: 0.1920, dev auc: 0.944, dev auprc: 0.726
# INFO:root:	Best dev auc so far: 0.944! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 2 took 3.53 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 3, Iter: 50, (part) train loss: 0.1969, (part) train auc: 0.946, (part) train auprc: 0.776, dev loss: 0.1802, dev auc: 0.947, dev auprc: 0.739
# INFO:root:	Best dev auc so far: 0.947! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 3, Iter: 60, (part) train loss: 0.1943, (part) train auc: 0.951, (part) train auprc: 0.789, dev loss: 0.1692, dev auc: 0.952, dev auprc: 0.762
# INFO:root:	Best dev auc so far: 0.952! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 3 took 4.96 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 4, Iter: 70, (part) train loss: 0.1821, (part) train auc: 0.954, (part) train auprc: 0.795, dev loss: 0.1792, dev auc: 0.952, dev auprc: 0.761
# INFO:root:	Best dev auc so far: 0.952! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 4, Iter: 80, (part) train loss: 0.1970, (part) train auc: 0.958, (part) train auprc: 0.811, dev loss: 0.1643, dev auc: 0.958, dev auprc: 0.783
# INFO:root:	Best dev auc so far: 0.958! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 4 took 4.90 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 5, Iter: 90, (part) train loss: 0.1944, (part) train auc: 0.956, (part) train auprc: 0.796, dev loss: 0.1706, dev auc: 0.953, dev auprc: 0.739
# INFO:root:Epoch 5 took 3.70 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 6, Iter: 100, (part) train loss: 0.1717, (part) train auc: 0.963, (part) train auprc: 0.830, dev loss: 0.1542, dev auc: 0.965, dev auprc: 0.800
# INFO:root:	Best dev auc so far: 0.965! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch: 6, Iter: 110, (part) train loss: 0.1796, (part) train auc: 0.965, (part) train auprc: 0.835, dev loss: 0.1483, dev auc: 0.966, dev auprc: 0.794
# INFO:root:	Best dev auc so far: 0.966! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 6 took 4.65 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 7, Iter: 120, (part) train loss: 0.1776, (part) train auc: 0.966, (part) train auprc: 0.844, dev loss: 0.1503, dev auc: 0.968, dev auprc: 0.808
# INFO:root:	Best dev auc so far: 0.968! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 7 took 3.75 seconds: 0.01 seconds for loading data
# INFO:root:Epoch: 8, Iter: 130, (part) train loss: 0.1867, (part) train auc: 0.966, (part) train auprc: 0.844, dev loss: 0.1477, dev auc: 0.967, dev auprc: 0.784
# INFO:root:Epoch: 8, Iter: 140, (part) train loss: 0.1363, (part) train auc: 0.967, (part) train auprc: 0.846, dev loss: 0.1438, dev auc: 0.971, dev auprc: 0.830
# INFO:root:	Best dev auc so far: 0.971! Saving best checkpoint to ./experiments/Demo/best_checkpoint/best.ckpt...
# INFO:root:Epoch 8 took 4.74 seconds: 0.02 seconds for loading data
# INFO:root:Epoch: 9, Iter: 150, (part) train loss: 0.1355, (part) train auc: 0.970, (part) train auprc: 0.858, dev loss: 0.1520, dev auc: 0.969, dev auprc: 0.802
# INFO:root:Epoch: 9, Iter: 160, (part) train loss: 0.1674, (part) train auc: 0.969, (part) train auprc: 0.854, dev loss: 0.1534, dev auc: 0.967, dev auprc: 0.786
# INFO:root:Epoch 9 took 4.45 seconds: 0.01 seconds for loading data

# %% [markdown]
#  For parameter specifications, please refer to the FLAGs definition in the `main.py` file.
